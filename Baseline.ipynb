# %%
import pandas as pd
import numpy as np
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %% [markdown]
# # Basic Info

# %%
spotify = pd.read_csv('./data/spotify_data/Spotify_Dataset_V3.csv', sep=';', parse_dates=['Date'], dayfirst=True)
spotify.head()
# Out:
#    Rank            Title                     Artists       Date  Danceability  \
# 0     1  Ella Baila Sola  Eslabon Armado, Peso Pluma 2023-05-29         0.668
# 1     1  Ella Baila Sola  Eslabon Armado, Peso Pluma 2023-05-29         0.668
# 2     2   WHERE SHE GOES                   Bad Bunny 2023-05-29         0.652
# 3     3  La Bebe - Remix       Yng Lvcas, Peso Pluma 2023-05-29         0.812
# 4     3  La Bebe - Remix       Yng Lvcas, Peso Pluma 2023-05-29         0.812
#
#    Energy  Loudness  Speechiness  Acousticness  Instrumentalness  Valence  \
# 0   0.758   -5176.0        0.033         0.483             0.000    0.834
# 1   0.758   -5176.0        0.033         0.483             0.000    0.834
# 2   0.800   -4019.0        0.061         0.143             0.629    0.234
# 3   0.479   -5678.0        0.333         0.213             0.000    0.559
# 4   0.479   -5678.0        0.333         0.213             0.000    0.559
#
#   # of Artist   Artist (Ind.) # of Nationality  Nationality      Continent  \
# 0    Artist 1  Eslabon Armado    Nationality 1       Mexico  Latin-America
# 1    Artist 2      Peso Pluma    Nationality 2       Mexico  Latin-America
# 2    Artist 1       Bad Bunny    Nationality 1  Puerto Rico  Latin-America
# 3    Artist 1       Yng Lvcas    Nationality 1       Mexico  Latin-America
# 4    Artist 2      Peso Pluma    Nationality 2       Mexico  Latin-America
#
#    Points (Total)  Points (Ind for each Artist/Nat)                      id  \
# 0             200                             100.0  3qQbCzHBycnDpGskqOWY0E
# 1             200                             100.0  3qQbCzHBycnDpGskqOWY0E
# 2             199                             199.0  7ro0hRteUMfnOioTFI5TG1
# 3             198                              99.0  2UW7JaomAMuX9pZrjVpHAU
# 4             198                              99.0  2UW7JaomAMuX9pZrjVpHAU
#
#                                             Song URL
# 0  https://open.spotify.com/track/3qQbCzHBycnDpGs...
# 1  https://open.spotify.com/track/3qQbCzHBycnDpGs...
# 2  https://open.spotify.com/track/7ro0hRteUMfnOio...
# 3  https://open.spotify.com/track/2UW7JaomAMuX9pZ...
# 4  https://open.spotify.com/track/2UW7JaomAMuX9pZ...

# %%
spotify.sort_index()
# Out:
#         Rank                          Title                     Artists  \
# 0          1                Ella Baila Sola  Eslabon Armado, Peso Pluma
# 1          1                Ella Baila Sola  Eslabon Armado, Peso Pluma
# 2          2                 WHERE SHE GOES                   Bad Bunny
# 3          3                La Bebe - Remix       Yng Lvcas, Peso Pluma
# 4          3                La Bebe - Remix       Yng Lvcas, Peso Pluma
# ...      ...                            ...                         ...
# 651931   197                        Oh Lord                   MiC LOWRY
# 651932   198  Superstition - Single Version               Stevie Wonder
# 651933   199                        Secrets                  The Weeknd
# 651934   200                Ni**as In Paris           JAY-Z, Kanye West
# 651935   200                Ni**as In Paris           JAY-Z, Kanye West
#
#              Date  Danceability  Energy  Loudness  Speechiness  Acousticness  \
# 0      2023-05-29         0.668   0.758   -5176.0        0.033         0.483
# 1      2023-05-29         0.668   0.758   -5176.0        0.033         0.483
# 2      2023-05-29         0.652   0.800   -4019.0        0.061         0.143
# 3      2023-05-29         0.812   0.479   -5678.0        0.333         0.213
# 4      2023-05-29         0.812   0.479   -5678.0        0.333         0.213
# ...           ...           ...     ...       ...          ...           ...
# 651931 2017-01-01         0.273   0.794   -6644.0        0.068         0.022
# 651932 2017-01-01         0.650   0.658  -10908.0        0.085         0.089
# 651933 2017-01-01         0.665   0.771   -5779.0        0.053         0.016
# 651934 2017-01-01         0.757   0.882   -6125.0        0.248         0.076
# 651935 2017-01-01         0.757   0.882   -6125.0        0.248         0.076
#
#         Instrumentalness  Valence # of Artist   Artist (Ind.)  \
# 0                  0.000    0.834    Artist 1  Eslabon Armado
# 1                  0.000    0.834    Artist 2      Peso Pluma
# 2                  0.629    0.234    Artist 1       Bad Bunny
# 3                  0.000    0.559    Artist 1       Yng Lvcas
# 4                  0.000    0.559    Artist 2      Peso Pluma
# ...                  ...      ...         ...             ...
# 651931             0.000    0.377    Artist 1       MiC LOWRY
# 651932             0.004    0.883    Artist 1   Stevie Wonder
# 651933             0.000    0.764    Artist 1      The Weeknd
# 651934             0.000    0.684    Artist 1           JAY-Z
# 651935             0.000    0.684    Artist 2      Kanye West
#
#        # of Nationality     Nationality      Continent  Points (Total)  \
# 0         Nationality 1          Mexico  Latin-America             200
# 1         Nationality 2          Mexico  Latin-America             200
# 2         Nationality 1     Puerto Rico  Latin-America             199
# 3         Nationality 1          Mexico  Latin-America             198
# 4         Nationality 2          Mexico  Latin-America             198
# ...                 ...             ...            ...             ...
# 651931    Nationality 1  United Kingdom         Europe               4
# 651932    Nationality 1   United States  Anglo-America               3
# 651933    Nationality 1          Canada  Anglo-America               2
# 651934    Nationality 1   United States  Anglo-America               1
# 651935    Nationality 2   United States  Anglo-America               1
#
#         Points (Ind for each Artist/Nat)                      id  \
# 0                                  100.0  3qQbCzHBycnDpGskqOWY0E
# 1                                  100.0  3qQbCzHBycnDpGskqOWY0E
# 2                                  199.0  7ro0hRteUMfnOioTFI5TG1
# 3                                   99.0  2UW7JaomAMuX9pZrjVpHAU
# 4                                   99.0  2UW7JaomAMuX9pZrjVpHAU
# ...                                  ...                     ...
# 651931                               4.0  1sTUEdVO85YU8Ymk2jeAls
# 651932                               3.0  5lXcSvHRVjQJ3LB2rLKQog
# 651933                               2.0  3DX4Y0egvc0slLcLl31h2p
# 651934                               1.0  2KpCpk6HjXXLb7nnXoXA5O
# 651935                               1.0  2KpCpk6HjXXLb7nnXoXA5O
#
#                                                  Song URL
# 0       https://open.spotify.com/track/3qQbCzHBycnDpGs...
# 1       https://open.spotify.com/track/3qQbCzHBycnDpGs...
# 2       https://open.spotify.com/track/7ro0hRteUMfnOio...
# 3       https://open.spotify.com/track/2UW7JaomAMuX9pZ...
# 4       https://open.spotify.com/track/2UW7JaomAMuX9pZ...
# ...                                                   ...
# 651931  https://open.spotify.com/track/1sTUEdVO85YU8Ym...
# 651932  https://open.spotify.com/track/5lXcSvHRVjQJ3LB...
# 651933  https://open.spotify.com/track/3DX4Y0egvc0slLc...
# 651934  https://open.spotify.com/track/2KpCpk6HjXXLb7n...
# 651935  https://open.spotify.com/track/2KpCpk6HjXXLb7n...
#
# [651936 rows x 20 columns]

# %%
spotify.shape
# Out:
# (651936, 20)

# %%
spotify.columns
# Out:
# Index(['Rank', 'Title', 'Artists', 'Date', 'Danceability', 'Energy',
#        'Loudness', 'Speechiness', 'Acousticness', 'Instrumentalness',
#        'Valence', '# of Artist', 'Artist (Ind.)', '# of Nationality',
#        'Nationality', 'Continent', 'Points (Total)',
#        'Points (Ind for each Artist/Nat)', 'id', 'Song URL'],
#       dtype='object')

# %%
spotify.describe()
# Out:
#                 Rank                           Date   Danceability  \
# count  651936.000000                         651936  651936.000000
# mean      100.407782  2020-03-26 22:03:35.226035200       0.697730
# min         1.000000            2017-01-01 00:00:00       0.073000
# 25%        51.000000            2018-08-23 00:00:00       0.617000
# 50%       100.000000            2020-03-16 00:00:00       0.719000
# 75%       150.000000            2021-11-16 00:00:00       0.793000
# max       200.000000            2023-05-29 00:00:00       0.985000
# std        57.406664                            NaN       0.133186
#
#               Energy       Loudness    Speechiness   Acousticness  \
# count  651936.000000  651936.000000  651936.000000  651936.000000
# mean        0.652049   -5295.645217       0.109946       0.230694
# min         0.005000  -34475.000000       0.022000       0.000000
# 25%         0.549000   -6825.000000       0.045000       0.048000
# 50%         0.671000   -5206.000000       0.068000       0.152000
# 75%         0.771000   -3885.000000       0.136000       0.349000
# max         0.996000    1509.000000       0.966000       0.994000
# std         0.155684    2785.261321       0.096841       0.230710
#
#        Instrumentalness        Valence  Points (Total)  \
# count     651936.000000  651936.000000   651936.000000
# mean           0.007647       0.523134      100.592218
# min            0.000000       0.026000        1.000000
# 25%            0.000000       0.356000       51.000000
# 50%            0.000000       0.521000      101.000000
# 75%            0.000000       0.696000      150.000000
# max            0.956000       0.982000      200.000000
# std            0.054724       0.223926       57.406664
#
#        Points (Ind for each Artist/Nat)
# count                     651936.000000
# mean                          72.391141
# min                            0.200000
# 25%                           28.000000
# 50%                           60.000000
# 75%                          104.000000
# max                          200.000000
# std                           54.227892

# %%
spotify['id'].value_counts()
# Out:
# id
# 6RUKPb4LETWmmr3iAEQktW    2602
# 0RiRZpuVRbi7oqRdSMwhQY    2596
# 7BKLCZ1jbUBVqRi2FVlTVw    2532
# 2VxeLyX666F8uXCJ0dZF8B    2504
# 0tgVpDi06FyKpA1z0VMD4v    2251
#                           ...
# 2chIkORxBLpPVgruGiMY8k       1
# 2fHZHwEp6TP2ClC1S8ihVN       1
# 4ow1etGbQ8kfbAT3QPlmhN       1
# 5f8OFV8uUTKhSFTmjinwFE       1
# 5euRP53moGQyGCsq8aNjvo       1
# Name: count, Length: 9161, dtype: int64

# %% [markdown]
# There are some tracks sharing same title

# %%
print(len(spotify['Title'].unique()))
print(len(spotify['id'].unique()))
# Out:
# 7457
# 9161

# %%
# check NaN：
spotify.isnull().values.any()
# Out:
# False

# %%
spotify[spotify['Date']=="2017-01-01"] # top 200 ranking per day
# Out:
#         Rank                          Title                   Artists  \
# 651678     1                        Starboy     The Weeknd, Daft Punk
# 651679     1                        Starboy     The Weeknd, Daft Punk
# 651680     2                         Closer  The Chainsmokers, Halsey
# 651681     2                         Closer  The Chainsmokers, Halsey
# 651682     3                Let Me Love You   DJ Snake, Justin Bieber
# ...      ...                            ...                       ...
# 651931   197                        Oh Lord                 MiC LOWRY
# 651932   198  Superstition - Single Version             Stevie Wonder
# 651933   199                        Secrets                The Weeknd
# 651934   200                Ni**as In Paris         JAY-Z, Kanye West
# 651935   200                Ni**as In Paris         JAY-Z, Kanye West
#
#              Date  Danceability  Energy  Loudness  Speechiness  Acousticness  \
# 651678 2017-01-01         0.681   0.594   -7028.0        0.282         0.165
# 651679 2017-01-01         0.681   0.594   -7028.0        0.282         0.165
# 651680 2017-01-01         0.748   0.524   -5599.0        0.034         0.414
# 651681 2017-01-01         0.748   0.524   -5599.0        0.034         0.414
# 651682 2017-01-01         0.476   0.718   -5309.0        0.058         0.078
# ...           ...           ...     ...       ...          ...           ...
# 651931 2017-01-01         0.273   0.794   -6644.0        0.068         0.022
# 651932 2017-01-01         0.650   0.658  -10908.0        0.085         0.089
# 651933 2017-01-01         0.665   0.771   -5779.0        0.053         0.016
# 651934 2017-01-01         0.757   0.882   -6125.0        0.248         0.076
# 651935 2017-01-01         0.757   0.882   -6125.0        0.248         0.076
#
#         Instrumentalness  Valence # of Artist     Artist (Ind.)  \
# 651678             0.000    0.535    Artist 1        The Weeknd
# 651679             0.000    0.535    Artist 2         Daft Punk
# 651680             0.000    0.661    Artist 1  The Chainsmokers
# 651681             0.000    0.661    Artist 2            Halsey
# 651682             0.000    0.142    Artist 1          DJ Snake
# ...                  ...      ...         ...               ...
# 651931             0.000    0.377    Artist 1         MiC LOWRY
# 651932             0.004    0.883    Artist 1     Stevie Wonder
# 651933             0.000    0.764    Artist 1        The Weeknd
# 651934             0.000    0.684    Artist 1             JAY-Z
# 651935             0.000    0.684    Artist 2        Kanye West
#
#        # of Nationality     Nationality      Continent  Points (Total)  \
# 651678    Nationality 1          Canada  Anglo-America             200
# 651679    Nationality 2          France         Europe             200
# 651680    Nationality 1   United States  Anglo-America             199
# 651681    Nationality 2   United States  Anglo-America             199
# 651682    Nationality 1         Germany         Europe             198
# ...                 ...             ...            ...             ...
# 651931    Nationality 1  United Kingdom         Europe               4
# 651932    Nationality 1   United States  Anglo-America               3
# 651933    Nationality 1          Canada  Anglo-America               2
# 651934    Nationality 1   United States  Anglo-America               1
# 651935    Nationality 2   United States  Anglo-America               1
#
#         Points (Ind for each Artist/Nat)                      id  \
# 651678                             100.0  5aAx2yezTd8zXrkmtKl66Z
# 651679                             100.0  5aAx2yezTd8zXrkmtKl66Z
# 651680                             100.0  7BKLCZ1jbUBVqRi2FVlTVw
# 651681                             100.0  7BKLCZ1jbUBVqRi2FVlTVw
# 651682                              99.0  4pdPtRcBmOSQDlJ3Fk945m
# ...                                  ...                     ...
# 651931                               4.0  1sTUEdVO85YU8Ymk2jeAls
# 651932                               3.0  5lXcSvHRVjQJ3LB2rLKQog
# 651933                               2.0  3DX4Y0egvc0slLcLl31h2p
# 651934                               1.0  2KpCpk6HjXXLb7nnXoXA5O
# 651935                               1.0  2KpCpk6HjXXLb7nnXoXA5O
#
#                                                  Song URL
# 651678  https://open.spotify.com/track/5aAx2yezTd8zXrk...
# 651679  https://open.spotify.com/track/5aAx2yezTd8zXrk...
# 651680  https://open.spotify.com/track/7BKLCZ1jbUBVqRi...
# 651681  https://open.spotify.com/track/7BKLCZ1jbUBVqRi...
# 651682  https://open.spotify.com/track/4pdPtRcBmOSQDlJ...
# ...                                                   ...
# 651931  https://open.spotify.com/track/1sTUEdVO85YU8Ym...
# 651932  https://open.spotify.com/track/5lXcSvHRVjQJ3LB...
# 651933  https://open.spotify.com/track/3DX4Y0egvc0slLc...
# 651934  https://open.spotify.com/track/2KpCpk6HjXXLb7n...
# 651935  https://open.spotify.com/track/2KpCpk6HjXXLb7n...
#
# [258 rows x 20 columns]

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# Dirty Data!

# %%
df1 = spotify[['Title', 'id']].drop_duplicates()
df2 =spotify[['Title', 'id']].drop_duplicates(subset=['id'])
Title1 = df1['Title'].values
Title2 = df2['Title'].values
dirty_data = np.setdiff1d(Title1, Title2, assume_unique=False)
print(len(dirty_data))
# Out:
# 39

# %%
spotify[spotify['id']=='6E90gq0KO6FYZVOXx8kCcC'][['Title', 'id','Nationality']].drop_duplicates()
# Out:
#                          Title                      id Nationality
# 129401    Astrout In The Ocean  6E90gq0KO6FYZVOXx8kCcC   Australia
# 150880  Astronaut In The Ocean  6E90gq0KO6FYZVOXx8kCcC   Australia

# %%
for title in dirty_data:
    index = spotify[spotify['Title']==title].iloc[0]['id']
    spotify.loc[spotify['id']==index, 'Title'] = title

# %%
spotify[spotify['id']=='6E90gq0KO6FYZVOXx8kCcC'][['Title', 'id','Nationality']].drop_duplicates()
# Out:
#                          Title                      id Nationality
# 129401  Astronaut In The Ocean  6E90gq0KO6FYZVOXx8kCcC   Australia

# %% [markdown]
# Data Cleaning Done

# %% [markdown]
# # Explore pattern of Danceability using points as weight

# %%
(spotify['Danceability'][spotify['Date']=='2023-05-29'][:3] * spotify['Points (Ind for each Artist/Nat)'][spotify['Date']=='2023-05-29'][:3]).sum()
# Out:
# 263.348

# %%
(spotify['Danceability'][spotify['Date']=='2023-05-29']*spotify['Points (Ind for each Artist/Nat)'][spotify['Date']=='2023-05-29']).sum()
# Out:
# 13327.492000001557

# %%
data_dict = {}
for col in ['Danceability', 'Energy', 'Loudness', 'Speechiness', 'Acousticness', 'Instrumentalness', 'Valence']:
    daily_list = []
    for date in spotify['Date'].sort_values().unique():
        spotify_date = spotify[spotify["Date"]==date]
        daily_feature = (spotify_date[col]*spotify_date['Points (Ind for each Artist/Nat)'] / 200).sum()
        daily_list.append(daily_feature)
    data_dict[col] = daily_list

# %%
df_features_daily = pd.DataFrame(data=data_dict, index=spotify['Date'].sort_values().unique())
df_features_daily.head()
# Out:
#             Danceability     Energy       Loudness  Speechiness  Acousticness  \
# 2017-01-01     69.377595  68.324210 -528449.376735    12.657880     18.185580
# 2017-01-02     68.676675  67.603040 -531479.766500    12.490530     18.928425
# 2017-01-03     68.670750  67.410175 -532916.107700    12.573005     18.957670
# 2017-01-04     68.591655  67.417870 -532262.555650    12.581075     18.929845
# 2017-01-05     68.640970  67.429635 -531019.541800    12.573120     19.031535
#
#             Instrumentalness    Valence
# 2017-01-01          0.849185  52.479965
# 2017-01-02          0.828535  50.730020
# 2017-01-03          0.859855  50.528910
# 2017-01-04          0.886650  50.433440
# 2017-01-05          0.897255  50.396855

# %%
for col in df_features_daily.columns:
    if col == 'Loudness':
        continue
    plt.plot(df_features_daily.index, df_features_daily[col], label=col)
# plt.legend(loc='upper right')
plt.xlabel('Date')
plt.ylabel('Score')
plt.title('Pattern of features')
plt.show()

# %%
spotify[spotify['Date'].dt.month == 12]['Title'].value_counts()
# Out:
# Title
# It's Beginning to Look a Lot Like Christmas (with Mitchell Ayres & His Orchestra)    542
# White Christmas                                                                      476
# Happy Xmas (War Is Over) - Remastered 2010                                           468
# Sunflower - Spider-Man: Into the Spider-Verse                                        254
# Quizas                                                                               248
#                                                                                     ...
# You Make My Dreams (Come True)                                                         1
# You Shook Me All Night Long                                                            1
# Tone Deaf                                                                              1
# thailand                                                                               1
# Respect the Game                                                                       1
# Name: count, Length: 1691, dtype: int64

# %%
df_features_daily[df_features_daily['Energy']==df_features_daily['Energy'].max()]
# Out:
#             Danceability     Energy      Loudness  Speechiness  Acousticness  \
# 2022-01-01     71.177985  70.703005 -507076.38845     9.252175      25.92803
#
#             Instrumentalness   Valence
# 2022-01-01          0.505705  60.46698

# %%
spotify[spotify['Date']=='2022-12-01'].sort_values(by='Rank')
# Out:
#        Rank                             Title  \
# 51664     1         Unholy (feat. Kim Petras)
# 51663     1         Unholy (feat. Kim Petras)
# 51425     2                         As It Was
# 51420     3   All I Want for Christmas Is You
# 51423     4                         Anti-Hero
# ...     ...                               ...
# 51446   197  Can't Hold Us (feat. Ray Dalton)
# 51507   198                          Hype Boy
# 51455   199                            DÁKITI
# 51454   199                            DÁKITI
# 51470   200                   drivers license
#
#                                                  Artists       Date  \
# 51664                              Sam Smith, Kim Petras 2022-12-01
# 51663                              Sam Smith, Kim Petras 2022-12-01
# 51425                                       Harry Styles 2022-12-01
# 51420                                       Mariah Carey 2022-12-01
# 51423                                       Taylor Swift 2022-12-01
# ...                                                  ...        ...
# 51446  Macklemore & Ryan Lewis, Macklemore, Ryan Lewi... 2022-12-01
# 51507                                           NewJeans 2022-12-01
# 51455                                  Bad Bunny, Jhayco 2022-12-01
# 51454                                  Bad Bunny, Jhayco 2022-12-01
# 51470                                     Olivia Rodrigo 2022-12-01
#
#        Danceability  Energy  Loudness  Speechiness  Acousticness  \
# 51664         0.714   0.472  -7375.00        0.086         0.013
# 51663         0.714   0.472  -7375.00        0.086         0.013
# 51425         0.520   0.731  -5338.00        0.056         0.342
# 51420         0.336   0.627  -7463.00        0.038         0.164
# 51423         0.637   0.643  -6571.00        0.052         0.130
# ...             ...     ...       ...          ...           ...
# 51446         0.633   0.927  -4468.00        0.084         0.027
# 51507         0.593   0.935     -3.43        0.225         0.268
# 51455         0.731   0.573 -10059.00        0.054         0.401
# 51454         0.731   0.573 -10059.00        0.054         0.401
# 51470         0.561   0.431     -8.81        0.058         0.768
#
#        Instrumentalness  Valence # of Artist   Artist (Ind.) # of Nationality  \
# 51664             0.000    0.238    Artist 2      Kim Petras    Nationality 2
# 51663             0.000    0.238    Artist 1       Sam Smith    Nationality 1
# 51425             0.001    0.662    Artist 1    Harry Styles    Nationality 1
# 51420             0.000    0.350    Artist 1    Mariah Carey    Nationality 1
# 51423             0.000    0.533    Artist 1    Taylor Swift    Nationality 1
# ...                 ...      ...         ...             ...              ...
# 51446             0.000    0.880    Artist 2      Macklemore    Nationality 2
# 51507             0.000    0.783    Artist 1        NewJeans    Nationality 1
# 51455             0.000    0.145    Artist 2          Jhayco    Nationality 2
# 51454             0.000    0.145    Artist 1       Bad Bunny    Nationality 1
# 51470             0.000    0.137    Artist 1  Olivia Rodrigo    Nationality 1
#
#           Nationality      Continent  Points (Total)  \
# 51664         Germany         Europe             200
# 51663  United Kingdom         Europe             200
# 51425  United Kingdom         Europe             199
# 51420   United States  Anglo-America             198
# 51423   United States  Anglo-America             197
# ...               ...            ...             ...
# 51446   United States  Anglo-America               4
# 51507     South Korea           Asia               3
# 51455     Puerto Rico  Latin-America               2
# 51454     Puerto Rico  Latin-America               2
# 51470   United States  Anglo-America               1
#
#        Points (Ind for each Artist/Nat)                      id  \
# 51664                             100.0  3nqQXoyQOWXiESFLlDF1hG
# 51663                             100.0  3nqQXoyQOWXiESFLlDF1hG
# 51425                             199.0  4Dvkj6JhhA12EX05fT7y2e
# 51420                             198.0  0bYg9bo50gSsH3LtXe2SQn
# 51423                             197.0  0V3wPSX9ygBnCm8psDIegu
# ...                                 ...                     ...
# 51446                               1.0  22skzmqfdWrjJylampe0kt
# 51507                               3.0  0a4MMyCrzT0En247IhqZbD
# 51455                               1.0  4MzXwWMhyBbmu6hOcLVD49
# 51454                               1.0  4MzXwWMhyBbmu6hOcLVD49
# 51470                               1.0  5wANPM4fQCJwkGd4rN57mH
#
#                                                 Song URL
# 51664  https://open.spotify.com/track/3nqQXoyQOWXiESF...
# 51663  https://open.spotify.com/track/3nqQXoyQOWXiESF...
# 51425  https://open.spotify.com/track/4Dvkj6JhhA12EX0...
# 51420  https://open.spotify.com/track/0bYg9bo50gSsH3L...
# 51423  https://open.spotify.com/track/0V3wPSX9ygBnCm8...
# ...                                                  ...
# 51446  https://open.spotify.com/track/22skzmqfdWrjJyl...
# 51507  https://open.spotify.com/track/0a4MMyCrzT0En24...
# 51455  https://open.spotify.com/track/4MzXwWMhyBbmu6h...
# 51454  https://open.spotify.com/track/4MzXwWMhyBbmu6h...
# 51470  https://open.spotify.com/track/5wANPM4fQCJwkGd...
#
# [273 rows x 20 columns]

# %%
from sklearn.linear_model import LinearRegression

y = df_features_daily["Danceability"]  # the target

# The intercept is the same as the `const` feature from
# DeterministicProcess. LinearRegression behaves badly with duplicated
# features, so we need to be sure to exclude it here.
model = LinearRegression(fit_intercept=False)
model.fit(X, y)

y_pred = pd.Series(model.predict(X), index=X.index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 9
#       5 # The intercept is the same as the `const` feature from
#       6 # DeterministicProcess. LinearRegression behaves badly with duplicated
#       7 # features, so we need to be sure to exclude it here.
#       8 model = LinearRegression(fit_intercept=False)
# ----> 9 model.fit(X, y)
#      11 y_pred = pd.Series(model.predict(X), index=X.index)
#
# NameError: name 'X' is not defined

# %%
ax = df_features_daily['Danceability'].plot(style=".", color="0.5", title="Danceability - Linear Trend")
_ = y_pred.plot(ax=ax, linewidth=3, label="Trend")

# %%
fig, axs = plt.subplots(6, sharex=True, sharey=True, figsize=(10, 15))
cols = ['Danceability', 'Energy', 'Speechiness', 'Acousticness', 'Instrumentalness', 'Valence']
for i in range(len(cols)):
    plot_periodogram(df_features_daily[cols[i]], col_name=cols[i], ax=axs[i])

# %%
from statsmodels.tsa.deterministic import DeterministicProcess

dp = DeterministicProcess(
    index=df_features_daily.index,  # dates from the training data
    constant=True,       # dummy feature for the bias (y_intercept)
    order=1,             # the time dummy (trend)
    drop=True,           # drop terms if necessary to avoid collinearity
)
# `in_sample` creates features for the dates given in the `index` argument
X = dp.in_sample()

X.head()
# Out:
#             const  trend
# 2017-01-01    1.0    1.0
# 2017-01-02    1.0    2.0
# 2017-01-03    1.0    3.0
# 2017-01-04    1.0    4.0
# 2017-01-05    1.0    5.0

# %% [markdown]
# ---

# %%
spotify_top = spotify[spotify['Rank']==1]
spotify_top.head()
# Out:
#      Rank            Title                     Artists       Date  \
# 0       1  Ella Baila Sola  Eslabon Armado, Peso Pluma 2023-05-29
# 1       1  Ella Baila Sola  Eslabon Armado, Peso Pluma 2023-05-29
# 295     1  Ella Baila Sola  Eslabon Armado, Peso Pluma 2023-05-28
# 296     1  Ella Baila Sola  Eslabon Armado, Peso Pluma 2023-05-28
# 589     1  Ella Baila Sola  Eslabon Armado, Peso Pluma 2023-05-27
#
#      Danceability  Energy  Loudness  Speechiness  Acousticness  \
# 0           0.668   0.758   -5176.0        0.033         0.483
# 1           0.668   0.758   -5176.0        0.033         0.483
# 295         0.668   0.758   -5176.0        0.033         0.483
# 296         0.668   0.758   -5176.0        0.033         0.483
# 589         0.668   0.758   -5176.0        0.033         0.483
#
#      Instrumentalness  Valence # of Artist   Artist (Ind.) # of Nationality  \
# 0                 0.0    0.834    Artist 1  Eslabon Armado    Nationality 1
# 1                 0.0    0.834    Artist 2      Peso Pluma    Nationality 2
# 295               0.0    0.834    Artist 1  Eslabon Armado    Nationality 1
# 296               0.0    0.834    Artist 2      Peso Pluma    Nationality 2
# 589               0.0    0.834    Artist 1  Eslabon Armado    Nationality 1
#
#     Nationality      Continent  Points (Total)  \
# 0        Mexico  Latin-America             200
# 1        Mexico  Latin-America             200
# 295      Mexico  Latin-America             200
# 296      Mexico  Latin-America             200
# 589      Mexico  Latin-America             200
#
#      Points (Ind for each Artist/Nat)                      id  \
# 0                               100.0  3qQbCzHBycnDpGskqOWY0E
# 1                               100.0  3qQbCzHBycnDpGskqOWY0E
# 295                             100.0  3qQbCzHBycnDpGskqOWY0E
# 296                             100.0  3qQbCzHBycnDpGskqOWY0E
# 589                             100.0  3qQbCzHBycnDpGskqOWY0E
#
#                                               Song URL
# 0    https://open.spotify.com/track/3qQbCzHBycnDpGs...
# 1    https://open.spotify.com/track/3qQbCzHBycnDpGs...
# 295  https://open.spotify.com/track/3qQbCzHBycnDpGs...
# 296  https://open.spotify.com/track/3qQbCzHBycnDpGs...
# 589  https://open.spotify.com/track/3qQbCzHBycnDpGs...

# %%
spotify_top.set_index('Date').sort_index()
# Out:
#             Rank            Title                     Artists  Danceability  \
# Date
# 2017-01-01     1          Starboy       The Weeknd, Daft Punk         0.681
# 2017-01-01     1          Starboy       The Weeknd, Daft Punk         0.681
# 2017-01-02     1          Starboy       The Weeknd, Daft Punk         0.681
# 2017-01-02     1          Starboy       The Weeknd, Daft Punk         0.681
# 2017-01-03     1          Starboy       The Weeknd, Daft Punk         0.681
# ...          ...              ...                         ...           ...
# 2023-05-27     1  Ella Baila Sola  Eslabon Armado, Peso Pluma         0.668
# 2023-05-28     1  Ella Baila Sola  Eslabon Armado, Peso Pluma         0.668
# 2023-05-28     1  Ella Baila Sola  Eslabon Armado, Peso Pluma         0.668
# 2023-05-29     1  Ella Baila Sola  Eslabon Armado, Peso Pluma         0.668
# 2023-05-29     1  Ella Baila Sola  Eslabon Armado, Peso Pluma         0.668
#
#             Energy  Loudness  Speechiness  Acousticness  Instrumentalness  \
# Date
# 2017-01-01   0.594   -7028.0        0.282         0.165               0.0
# 2017-01-01   0.594   -7028.0        0.282         0.165               0.0
# 2017-01-02   0.594   -7028.0        0.282         0.165               0.0
# 2017-01-02   0.594   -7028.0        0.282         0.165               0.0
# 2017-01-03   0.594   -7028.0        0.282         0.165               0.0
# ...            ...       ...          ...           ...               ...
# 2023-05-27   0.758   -5176.0        0.033         0.483               0.0
# 2023-05-28   0.758   -5176.0        0.033         0.483               0.0
# 2023-05-28   0.758   -5176.0        0.033         0.483               0.0
# 2023-05-29   0.758   -5176.0        0.033         0.483               0.0
# 2023-05-29   0.758   -5176.0        0.033         0.483               0.0
#
#             Valence # of Artist   Artist (Ind.) # of Nationality Nationality  \
# Date
# 2017-01-01    0.535    Artist 2       Daft Punk    Nationality 2      France
# 2017-01-01    0.535    Artist 1      The Weeknd    Nationality 1      Canada
# 2017-01-02    0.535    Artist 1      The Weeknd    Nationality 1      Canada
# 2017-01-02    0.535    Artist 2       Daft Punk    Nationality 2      France
# 2017-01-03    0.535    Artist 1      The Weeknd    Nationality 1      Canada
# ...             ...         ...             ...              ...         ...
# 2023-05-27    0.834    Artist 1  Eslabon Armado    Nationality 1      Mexico
# 2023-05-28    0.834    Artist 2      Peso Pluma    Nationality 2      Mexico
# 2023-05-28    0.834    Artist 1  Eslabon Armado    Nationality 1      Mexico
# 2023-05-29    0.834    Artist 2      Peso Pluma    Nationality 2      Mexico
# 2023-05-29    0.834    Artist 1  Eslabon Armado    Nationality 1      Mexico
#
#                 Continent  Points (Total)  Points (Ind for each Artist/Nat)  \
# Date
# 2017-01-01         Europe             200                             100.0
# 2017-01-01  Anglo-America             200                             100.0
# 2017-01-02  Anglo-America             200                             100.0
# 2017-01-02         Europe             200                             100.0
# 2017-01-03  Anglo-America             200                             100.0
# ...                   ...             ...                               ...
# 2023-05-27  Latin-America             200                             100.0
# 2023-05-28  Latin-America             200                             100.0
# 2023-05-28  Latin-America             200                             100.0
# 2023-05-29  Latin-America             200                             100.0
# 2023-05-29  Latin-America             200                             100.0
#
#                                 id  \
# Date
# 2017-01-01  5aAx2yezTd8zXrkmtKl66Z
# 2017-01-01  5aAx2yezTd8zXrkmtKl66Z
# 2017-01-02  5aAx2yezTd8zXrkmtKl66Z
# 2017-01-02  5aAx2yezTd8zXrkmtKl66Z
# 2017-01-03  5aAx2yezTd8zXrkmtKl66Z
# ...                            ...
# 2023-05-27  3qQbCzHBycnDpGskqOWY0E
# 2023-05-28  3qQbCzHBycnDpGskqOWY0E
# 2023-05-28  3qQbCzHBycnDpGskqOWY0E
# 2023-05-29  3qQbCzHBycnDpGskqOWY0E
# 2023-05-29  3qQbCzHBycnDpGskqOWY0E
#
#                                                      Song URL
# Date
# 2017-01-01  https://open.spotify.com/track/5aAx2yezTd8zXrk...
# 2017-01-01  https://open.spotify.com/track/5aAx2yezTd8zXrk...
# 2017-01-02  https://open.spotify.com/track/5aAx2yezTd8zXrk...
# 2017-01-02  https://open.spotify.com/track/5aAx2yezTd8zXrk...
# 2017-01-03  https://open.spotify.com/track/5aAx2yezTd8zXrk...
# ...                                                       ...
# 2023-05-27  https://open.spotify.com/track/3qQbCzHBycnDpGs...
# 2023-05-28  https://open.spotify.com/track/3qQbCzHBycnDpGs...
# 2023-05-28  https://open.spotify.com/track/3qQbCzHBycnDpGs...
# 2023-05-29  https://open.spotify.com/track/3qQbCzHBycnDpGs...
# 2023-05-29  https://open.spotify.com/track/3qQbCzHBycnDpGs...
#
# [3057 rows x 19 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

for col in ['Danceability', 'Energy', 'Loudness', 'Speechiness', 'Acousticness', 'Instrumentalness', 'Valence']:
    spotify_top.loc[:,col] = scaler.fit_transform(spotify_top[col].values.reshape(-1,1))

# %%
spotify_top.describe()
# Out:
#          Rank                           Date  Danceability       Energy  \
# count  3057.0                           3057   3057.000000  3057.000000
# mean      1.0  2020-01-20 11:19:15.250245632      0.581740     0.535241
# min       1.0            2017-01-01 00:00:00      0.000000     0.000000
# 25%       1.0            2018-03-05 00:00:00      0.422886     0.406166
# 50%       1.0            2019-12-03 00:00:00      0.603648     0.538874
# 75%       1.0            2021-10-13 00:00:00      0.701493     0.686327
# max       1.0            2023-05-29 00:00:00      1.000000     1.000000
# std       0.0                            NaN      0.177622     0.181140
#
#           Loudness  Speechiness  Acousticness  Instrumentalness      Valence  \
# count  3057.000000  3057.000000   3057.000000       3057.000000  3057.000000
# mean      0.582562     0.195649      0.265829          0.007186     0.512856
# min       0.000000     0.000000      0.000000          0.000000     0.000000
# 25%       0.489870     0.057637      0.042530          0.000000     0.312856
# 50%       0.589588     0.149856      0.248637          0.000000     0.544937
# 75%       0.696226     0.265130      0.372955          0.000000     0.792947
# max       1.000000     1.000000      1.000000          1.000000     1.000000
# std       0.157401     0.218194      0.236395          0.042696     0.279487
#
#        Points (Total)  Points (Ind for each Artist/Nat)
# count          3057.0                       3057.000000
# mean            200.0                        152.864246
# min             200.0                         67.000000
# 25%             200.0                        100.000000
# 50%             200.0                        200.000000
# 75%             200.0                        200.000000
# max             200.0                        200.000000
# std               0.0                         54.307644

# %%
moving_average = spotify_top[['Danceability', 'Energy', 'Loudness', 'Speechiness', 'Acousticness', 'Instrumentalness', 'Valence']].rolling(
    window=365,       # 365-day window
    center=True,      # puts the average at the center of the window
    min_periods=183,  # choose about half the window size
).mean()

# %%
moving_average.plot(
    linewidth=3, title="Features - 365-Day Moving Average", legend=True,
);

# %%
import matplotlib.pyplot as plt 

def plot_periodogram(ts, col_name, detrend='linear', ax=None):
    from scipy.signal import periodogram
    fs = pd.Timedelta("365D") / pd.Timedelta("1D")
    freqencies, spectrum = periodogram(
        ts,
        fs=fs,
        detrend=detrend,
        window="boxcar",
        scaling='spectrum',
    )
    if ax is None:
        _, ax = plt.subplots()
    ax.step(freqencies, spectrum, color="purple")
    ax.set_xscale("log")
    ax.set_xticks([1, 2, 4, 6, 12, 26, 52, 104])
    ax.set_xticklabels(
        [
            "Annual (1)",
            "Semiannual (2)",
            "Quarterly (4)",
            "Bimonthly (6)",
            "Monthly (12)",
            "Biweekly (26)",
            "Weekly (52)",
            "Semiweekly (104)",
        ],
        rotation=30,
    )
    ax.ticklabel_format(axis="y", style="sci", scilimits=(0, 0))
#     ax.set_ylabel("Variance")
    ax.set_title(col_name)
    return ax

# %%
fig, axs = plt.subplots(7, sharex=True, sharey=True, figsize=(10, 15))
cols = ['Danceability', 'Energy', 'Loudness', 'Speechiness', 'Acousticness', 'Instrumentalness', 'Valence']
for i in range(len(cols)):
    plot_periodogram(spotify_top[cols[i]], col_name=cols[i], ax=axs[i])

# %% [markdown]
# # Data Distribution Analysis

# %%
sns.histplot(data=spotify, x='Continent')
# Out:
# D:\APP\Anaconda\envs\AML\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# D:\APP\Anaconda\envs\AML\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# D:\APP\Anaconda\envs\AML\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Continent', ylabel='Count'>

# %% [markdown]
# # Explore the relationship among features associated with tracks and the points

# %% [markdown]
# ### Baseline -- should better than this

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler,  OneHotEncoder
from sklearn.compose import make_column_transformer, make_column_selector
from sklearn.model_selection import train_test_split
import numpy as np

# %%
# median_array = np.full_like(y_val, np.median(y_train))

# print("MAE: {}".format(mean_absolute_error(y_val, median_array)))
# Out:
# MAE: 49.50530306826343

# %%
selected_columns = ['Danceability', 'Energy', 'Loudness', 'Speechiness', 'Acousticness', 'Instrumentalness', 'Valence', 'Points (Total)']
df = spotify[(spotify['Date']>='2017-01-01') & (spotify['Date']<'2018-01-01')][selected_columns]
df.head()
# Out:
#         Danceability  Energy  Loudness  Speechiness  Acousticness  \
# 555508         0.620   0.574   -7788.0        0.048         0.569
# 555509         0.620   0.574   -7788.0        0.048         0.569
# 555510         0.620   0.574   -7788.0        0.048         0.569
# 555511         0.818   0.803   -4282.0        0.080         0.034
# 555512         0.548   0.650   -5827.0        0.059         0.219
#
#         Instrumentalness  Valence  Points (Total)
# 555508               0.0    0.357             167
# 555509               0.0    0.357             167
# 555510               0.0    0.357             167
# 555511               0.0    0.632              44
# 555512               0.0    0.557              74

# %%
X = df.drop('Points (Total)', axis=1)
y = df['Points (Total)']

X_train,X_val,y_train,y_val=train_test_split(X,y,test_size=0.3,random_state=0)

preprocessor = make_column_transformer(
    (StandardScaler(),
    make_column_selector(dtype_include=np.number)),
)

X_train_std = preprocessor.fit_transform(X_train)
X_val =  preprocessor.transform(X_val)

clf = LinearRegression().fit(X_train_std, y_train)
preds = clf.predict(X_val)
from sklearn.metrics import mean_absolute_error

print("MAE: {}".format(mean_absolute_error(y_val, preds)))
# Out:
# MAE: 49.46629838767801

# %%
selected_columns = ['Danceability', 'Energy', 'Loudness', 'Speechiness', 'Acousticness', 'Instrumentalness', 'Valence', 'Points (Total)']
df = spotify[(spotify['Date']>='2017-01-01') & (spotify['Date']<'2019-01-01')][selected_columns]
df.head()
# Out:
#         Danceability  Energy  Loudness  Speechiness  Acousticness  \
# 452367         0.697   0.683  -2881.00        0.117         0.037
# 452368         0.837   0.636  -7643.00        0.086         0.040
# 452369         0.767   0.709     -4.47        0.336         0.323
# 452370         0.788   0.771  -3206.00        0.056         0.291
# 452371         0.788   0.771  -3206.00        0.056         0.291
#
#         Instrumentalness  Valence  Points (Total)
# 452367             0.000    0.603             131
# 452368             0.001    0.274             127
# 452369             0.000    0.720             190
# 452370             0.000    0.701             156
# 452371             0.000    0.701             156

# %%
X = df.drop('Points (Total)', axis=1)
y = df['Points (Total)']

X_train,X_val,y_train,y_val=train_test_split(X,y,test_size=0.3,random_state=0)

preprocessor = make_column_transformer(
    (StandardScaler(),
    make_column_selector(dtype_include=np.number)),
)

X_train_std = preprocessor.fit_transform(X_train)
X_val =  preprocessor.transform(X_val)

clf = LinearRegression().fit(X_train_std, y_train)
preds = clf.predict(X_val)
from sklearn.metrics import mean_absolute_error

print("MAE: {}".format(mean_absolute_error(y_val, preds)))
# Out:
# MAE: 49.305571996232786

# %% [markdown]
# # Are popularity related to Nationality?

# %%
selected_columns = ['Danceability', 'Energy', 'Loudness', 'Speechiness', 'Acousticness', 'Instrumentalness', 'Valence', 'Nationality', 'Points (Total)']
df = spotify[(spotify['Date']>='2017-01-01') & (spotify['Date']<'2018-01-01')][selected_columns]
df.head()
# Out:
#         Danceability  Energy  Loudness  Speechiness  Acousticness  \
# 555508         0.620   0.574   -7788.0        0.048         0.569
# 555509         0.620   0.574   -7788.0        0.048         0.569
# 555510         0.620   0.574   -7788.0        0.048         0.569
# 555511         0.818   0.803   -4282.0        0.080         0.034
# 555512         0.548   0.650   -5827.0        0.059         0.219
#
#         Instrumentalness  Valence    Nationality  Points (Total)
# 555508               0.0    0.357  United States             167
# 555509               0.0    0.357         Canada             167
# 555510               0.0    0.357  United States             167
# 555511               0.0    0.632  United States              44
# 555512               0.0    0.557         France              74

# %%
X = df.drop('Points (Total)', axis=1)
y = df['Points (Total)']

X_train,X_val,y_train,y_val=train_test_split(X,y,test_size=0.3,random_state=0)

preprocessor = make_column_transformer(
    (StandardScaler(),
    make_column_selector(dtype_include=np.number)),
    (OneHotEncoder(sparse=False),
    make_column_selector(dtype_include=object))
)

X_train_std = preprocessor.fit_transform(X_train)
X_val =  preprocessor.transform(X_val)

clf = LinearRegression().fit(X_train_std, y_train)
preds = clf.predict(X_val)
from sklearn.metrics import mean_absolute_error

print("MAE: {}".format(mean_absolute_error(y_val, preds)))
# Out:
# MAE: 48.95977985940471
# D:\APP\Anaconda\envs\AML\lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# # Take Date Interval into Count

# %% [markdown]
# ## A trend of becoming less popular with time

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler,  OneHotEncoder, PolynomialFeatures
from sklearn.compose import make_column_transformer, make_column_selector
from sklearn.model_selection import train_test_split
import numpy as np

# %%
selected_columns = ['id', 'Danceability', 'Energy', 'Loudness', 'Speechiness', 'Acousticness', 'Instrumentalness', 'Valence', 'Nationality', 'Date', 'Points (Total)']
df = spotify[(spotify['Date']>='2017-01-01') & (spotify['Date']<'2018-01-01')][selected_columns]
df.head()

for idx in df['id'].unique():
    df.loc[spotify['id']==idx, 'Date_Interval'] = df[df['id']==idx]['Date'] - df[df['id']==idx]['Date'].min()

# %%
df['Date_Interval_num'] = df['Date_Interval'].dt.days

# %%
sns.lineplot(df, x='Date_Interval_num', y='Points (Total)')
plt.title('Relation between Date Interval and Points')
# Out:
# D:\APP\Anaconda\envs\AML\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# D:\APP\Anaconda\envs\AML\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# D:\APP\Anaconda\envs\AML\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\APP\Anaconda\envs\AML\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 1.0, 'Relation between Date Interval and Points')

# %%
df.describe()
# Out:
#        Danceability        Energy      Loudness   Speechiness  Acousticness  \
# count  96428.000000  96428.000000  96428.000000  96428.000000  96428.000000
# mean       0.695120      0.664833  -5282.595575      0.110562      0.184057
# min        0.125000      0.028000 -34475.000000      0.023000      0.000000
# 25%        0.627000      0.555000  -6696.000000      0.048000      0.041000
# 50%        0.708000      0.678000  -5334.000000      0.069000      0.116000
# 75%        0.780000      0.798000  -4024.000000      0.134000      0.246000
# max        0.957000      0.995000     -0.020000      0.954000      0.994000
# std        0.122864      0.158478   2548.599017      0.096095      0.192791
#
#        Instrumentalness       Valence                           Date  \
# count      96428.000000  96428.000000                          96428
# mean           0.006321      0.505834  2017-07-04 18:24:15.112622848
# min            0.000000      0.037000            2017-01-01 00:00:00
# 25%            0.000000      0.354000            2017-04-04 00:00:00
# 50%            0.000000      0.501000            2017-07-07 00:00:00
# 75%            0.000000      0.679000            2017-10-05 00:00:00
# max            0.903000      0.982000            2017-12-31 00:00:00
# std            0.045329      0.218183                            NaN
#
#        Points (Total)               Date_Interval  Date_Interval_num
# count    96428.000000                       96428       96428.000000
# mean       101.817563  90 days 17:19:41.681669225          90.722010
# min          1.000000             0 days 00:00:00           0.000000
# 25%         52.000000            24 days 00:00:00          24.000000
# 50%        102.500000            66 days 00:00:00          66.000000
# 75%        151.000000           138 days 00:00:00         138.000000
# max        200.000000           364 days 00:00:00         364.000000
# std         57.542869  81 days 23:30:05.165797838          81.979226

# %%
X = df.drop(['id','Points (Total)'], axis=1)
y = df['Points (Total)']

X_train,X_val,y_train,y_val=train_test_split(X,y,test_size=0.3,random_state=0)

preprocessor = make_column_transformer(
    (StandardScaler(),
    make_column_selector(dtype_include=np.number)),
    (OneHotEncoder(sparse=False),
    make_column_selector(dtype_include=object))
)

X_train_std = preprocessor.fit_transform(X_train)
X_val =  preprocessor.transform(X_val)

clf = LinearRegression().fit(X_train_std, y_train)
preds = clf.predict(X_val)
from sklearn.metrics import mean_absolute_error

print("MAE: {}".format(mean_absolute_error(y_val, preds)))
# Out:
# MAE: 47.71489904742717
# D:\APP\Anaconda\envs\AML\lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
# Polynominal degree=2
df['Date_Interval'] = df['Date_Interval'].dt.days ** 2

X = df.drop(['id','Points (Total)'], axis=1)
y = df['Points (Total)']

X_train,X_val,y_train,y_val=train_test_split(X,y,test_size=0.3,random_state=0)

preprocessor = make_column_transformer(
    (StandardScaler(),
    make_column_selector(dtype_include=np.number)),
    (OneHotEncoder(sparse=False),
    make_column_selector(dtype_include=object))
)

X_train_std = preprocessor.fit_transform(X_train)
X_val =  preprocessor.transform(X_val)

clf = LinearRegression().fit(X_train_std, y_train)
preds = clf.predict(X_val)
from sklearn.metrics import mean_absolute_error

print("MAE: {}".format(mean_absolute_error(y_val, preds)))
# Out:
# MAE: 47.383343035802355
# D:\APP\Anaconda\envs\AML\lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# # DecisionTreeRegression

# %%
from sklearn.tree import DecisionTreeRegressor

X = df.drop('Points (Total)', axis=1)
y = df['Points (Total)']

X_train,X_val,y_train,y_val=train_test_split(X,y,test_size=0.3,random_state=0)

preprocessor = make_column_transformer(
    (StandardScaler(),
    make_column_selector(dtype_include=np.number)),
)

X_train_std = preprocessor.fit_transform(X_train)
X_val =  preprocessor.transform(X_val)

clf = DecisionTreeRegressor(random_state=0, criterion='absolute_error').fit(X_train_std, y_train)
preds = clf.predict(X_val)
from sklearn.metrics import mean_absolute_error

print("MAE: {}".format(mean_absolute_error(y_val, preds)))
# Out:
# MAE: 29.82355076221093

# %%
X = df.drop(['id','Points (Total)', 'Date_Interval'], axis=1)
y = df['Points (Total)']

X_train,X_val,y_train,y_val=train_test_split(X,y,test_size=0.3,random_state=0)

preprocessor = make_column_transformer(
    (StandardScaler(),
    make_column_selector(dtype_include=np.number)),
    (OneHotEncoder(sparse_output=False),
    make_column_selector(dtype_include=object))
)

X_train_std = preprocessor.fit_transform(X_train)
X_val =  preprocessor.transform(X_val)

clf = DecisionTreeRegressor(random_state=0, criterion='absolute_error').fit(X_train_std, y_train)
preds = clf.predict(X_val)

from sklearn.metrics import mean_absolute_error
print("MAE: {}".format(mean_absolute_error(y_val, preds)))
# Out:
# D:\APP\Anaconda\envs\AML\lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# MAE: 5.600660237132289
